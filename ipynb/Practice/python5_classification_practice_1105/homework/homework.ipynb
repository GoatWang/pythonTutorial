# %%
# if you have installed brew: /usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"
# brew install tesseract
# pip install opencv-python
from PIL import Image
import pytesseract
import cv2
import os
from pprint import pprint
from matplotlib import pyplot as plt

# %%
image = cv2.imread("images/1.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]÷
# gray = cv2.medianBlur(gray, 3)

# %%
fig, ax = plt.subplots(figsize=(100, 20))
ax.imshow(image)
plt.show()

fig, ax = plt.subplots(figsize=(100, 20))
plt.imshow(gray)
plt.show()

# %%
filename = "{}.png".format(os.getpid())
cv2.imwrite(filename, gray)
text = pytesseract.image_to_string(Image.open(filename))
pprint(text)
# Out:
# ('The internship\n'
#  '\n'
#  'The internship is a paid, fulltime, fourimonth program (February 7 May) at '
#  "one of EVRY's Hubs in\n"
#  'Norway or Sweden. As an intern in the Labs, you will contribute to create '
#  'business value to EVRY and\n'
#  'our customers. Through whitepapers you will explain how emerging '
#  'technologies and industry trends\n'
#  'are shaping the future of our society, and through prototypes you will '
#  'answer the challenges with\n'
#  'solutions. Relevant technologies and trends could be Artiﬁcial Intelligence '
#  '(A.l.), Internet of Things\n'
#  '(loT), Blockchain, PeeritoiPeer (P2P) lending, Crowdfunding, '
#  'BankiasiaiPlatform (BaaP), etc. Your role\n'
#  '\n'
#  'is to become the expert in your topic and share your analysis and '
#  'predictions with EVRY, our\n'
#  'customers and the rest of the world.')

# %%
text = pytesseract.image_to_string(Image.open("images/0.png"))
text
# Out:
# "EVRY is one 0! me leading \\T companies in lhe Nordic veq'an. Through ideas, technology and\nsolutions, EVRV brings inﬁmnaﬁon to Me, creating vz‘uelovits cumers' businessesznd making a\npositive oomribulion to socieqy. EVRV com es extensive indushy experience with a eusmma\ncenlric appvoach, and inlemaﬁonal capabﬂiﬁes Wm. |cca‘ pvesence Ia he‘p cumevs realize (he mu\neenennal 07 n. We operate in indus1ries such as ﬁnance, hea‘lh, insurance, pub‘ic, telecoms, ml and\n\ngas.\n\n \n\nThe intemship\nThe imemship is a paid, Mmme, lourmomh program (February , May) at ene 0| EVRV's Hubs in\nNorway or Sweden. As an imem 7n Ihe Labs, yuu Wm ccnlribme to cyeme business \\mlue lo EVRV and\nour mmmevs. Through whifepapers you win explain how emeygmg lechnobgies and inemy weeds\nare shaping me Mme 0| cur sociely, and mmugh pvolmypes yuu Mu answedhe challenges wuh\nsolutions. Relmnt technologies and heads eomd be Anmem Intelligence (AL), Inlemet d Things\n(loT), Bleehehain, PeeHnPeet (P1P) lending, medmnding, BanknsrarP‘aﬂovm (BaaP‘), etc. Your role\nis lo beeome Ihe experl in yourmpic and share yum analysis and predictions Wm. EVRV, em\ncuslomers and me .emuhe world.\n\nThe denveyeues in EVRV's Inmﬁon Labsare whﬂepapen, cemepcs/mnetypee, cus‘omy cases\nand inlemal prejeetse depending on yourqualiiies. Common for menu is lhal all ave Vocused enimure\nlechnobgies and solmiens lo challenges in our society."

# %%
from pprint import pprint
pprint(text)
# Out:
# ("EVRY is one 0! me leading \\T companies in lhe Nordic veq'an. Through ideas, "
#  'technology and\n'
#  "solutions, EVRV brings inﬁmnaﬁon to Me, creating vz‘uelovits cumers' "
#  'businessesznd making a\n'
#  'positive oomribulion to socieqy. EVRV com es extensive indushy experience '
#  'with a eusmma\n'
#  'cenlric appvoach, and inlemaﬁonal capabﬂiﬁes Wm. |cca‘ pvesence Ia he‘p '
#  'cumevs realize (he mu\n'
#  'eenennal 07 n. We operate in indus1ries such as ﬁnance, hea‘lh, insurance, '
#  'pub‘ic, telecoms, ml and\n'
#  '\n'
#  'gas.\n'
#  '\n'
#  ' \n'
#  '\n'
#  'The intemship\n'
#  'The imemship is a paid, Mmme, lourmomh program (February , May) at ene 0| '
#  "EVRV's Hubs in\n"
#  'Norway or Sweden. As an imem 7n Ihe Labs, yuu Wm ccnlribme to cyeme business '
#  '\\mlue lo EVRV and\n'
#  'our mmmevs. Through whifepapers you win explain how emeygmg lechnobgies and '
#  'inemy weeds\n'
#  'are shaping me Mme 0| cur sociely, and mmugh pvolmypes yuu Mu answedhe '
#  'challenges wuh\n'
#  'solutions. Relmnt technologies and heads eomd be Anmem Intelligence (AL), '
#  'Inlemet d Things\n'
#  '(loT), Bleehehain, PeeHnPeet (P1P) lending, medmnding, BanknsrarP‘aﬂovm '
#  '(BaaP‘), etc. Your role\n'
#  'is lo beeome Ihe experl in yourmpic and share yum analysis and predictions '
#  'Wm. EVRV, em\n'
#  'cuslomers and me .emuhe world.\n'
#  '\n'
#  "The denveyeues in EVRV's Inmﬁon Labsare whﬂepapen, cemepcs/mnetypee, cus‘omy "
#  'cases\n'
#  'and inlemal prejeetse depending on yourqualiiies. Common for menu is lhal '
#  'all ave Vocused enimure\n'
#  'lechnobgies and solmiens lo challenges in our society.')
